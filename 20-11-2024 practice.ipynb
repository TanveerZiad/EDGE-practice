# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_details(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

book1 = Book("Pother Pachali", "Bibhutibhushan Bandyopadhyay", 1929)
book2 = Book("Chokher Bali", "Rabindranath Tagore", 1903)

print(book1.get_details())
print(book2.get_details())
# Out:
# Title: Pother Pachali, Author: Bibhutibhushan Bandyopadhyay, Year Published: 1929
# Title: Chokher Bali, Author: Rabindranath Tagore, Year Published: 1903

# %%
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Woof")


dog = Dog()
dog.speak()
# Out:
# Woof

# %%
class BankAccount:
    def __init__(self, initial_balance):
        self._balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Deposited {amount}. New balance: {self._balance}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > 0:
            if self._balance >= amount:
                self._balance -= amount
                print(f"Withdrew {amount}. New balance: {self._balance}")
            else:
                print("Insufficient balance for withdrawal.")
        else:
            print("Withdrawal amount must be positive.")

    def get_balance(self):
        return self._balance

account = BankAccount(500)

account.deposit(200)
account.withdraw(100)
account.withdraw(700)

print("Final balance:", account.get_balance())
# Out:
# Deposited 200. New balance: 700
# Withdrew 100. New balance: 600
# Insufficient balance for withdrawal.
# Final balance: 600

# %%
import math

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Area of Circle:", circle.area())
print("Area of Rectangle:", rectangle.area())
# Out:
# Area of Circle: 78.53981633974483
# Area of Rectangle: 24

# %%
class MathOperations:
    @staticmethod
    def multiply(x, y):
        return x * y

result = MathOperations.multiply(4, 5)
print("The product is:", result)
# Out:
# The product is: 20

# %%
class Calculator:
    def add(self, *args):
        if len(args) == 2:
            return args[0] + args[1]
        elif len(args) == 1 and isinstance(args[0], list):
            return sum(args[0])
        else:
            return "Invalid input"

calc = Calculator()
print("Sum of two numbers:", calc.add(5, 3))
print("Sum of a list of numbers:", calc.add([1, 2, 3, 4, 5]))
print("Invalid input:", calc.add("a", "b"))
# Out:
# Sum of two numbers: 8
# Sum of a list of numbers: 15
# Invalid input: ab

# %%
class Employee:

    company_name = "TechCorp"

    def __init__(self, name, position):

        self.name = name
        self.position = position

    def display(self):

        print(f"Name: {self.name}, Position: {self.position}, Company: {Employee.company_name}")


employee1 = Employee("Showaib", "Software Engineer")
employee2 = Employee("Tanveer", "Data Scientist")

employee1.display()
employee2.display()
# Out:
# Name: Showaib, Position: Software Engineer, Company: TechCorp
# Name: Tanveer, Position: Data Scientist, Company: TechCorp

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def __repr__(self):

        return f"Car(make='{self.make}', model='{self.model}', year={self.year})"

car1 = Car("Tesla", "Model S", 2022)

print(car1)
# Out:
# Car(make='Tesla', model='Model S', year=2022)

# %%
class Vehicle:
    def __init__(self, make, model):
        self.make = make
        self.model = model

class Truck(Vehicle):
    def __init__(self, make, model, payload_capacity):

        super().__init__(make, model)

        self.payload_capacity = payload_capacity

    def get_details(self):
        return f"Truck(make='{self.make}', model='{self.model}', payload_capacity={self.payload_capacity} kg)"

truck1 = Truck("Ford", "F-150", 2000)

print(truck1.get_details())
# Out:
# Truck(make='Ford', model='F-150', payload_capacity=2000 kg)
